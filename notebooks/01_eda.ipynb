# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../data/creditcard.csv")
print(df.shape)
df.info()
df.head()
# Out:
# (284807, 31)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
# ...

# %%
class_counts = df["Class"].value_counts()
class_pct = df["Class"].value_counts(normalize=True) * 100
print(class_counts)
print(class_pct)

sns.countplot(x="Class", data=df)
plt.title("Class Distribution (0 = Legit, 1 = Fraud)")
plt.yscale("log")  # log scale, otherwise fraud bar is invisible
plt.show()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64
# Class
# 0    99.827251
# 1     0.172749
# Name: proportion, dtype: float64

# %%
df.isnull().sum().sum()  # should be 0 for this dataset
# Out:
# np.int64(0)

# %%
fig, ax = plt.subplots(1, 2, figsize=(14, 4))
sns.histplot(df[df.Class == 0]["Amount"], bins=50, ax=ax[0])
ax[0].set_title("Legitimate Transaction Amounts")
sns.histplot(df[df.Class == 1]["Amount"], bins=50, ax=ax[1])
ax[1].set_title("Fraudulent Transaction Amounts")
plt.show()

df.groupby("Class")["Amount"].describe()
# Out:
#           count        mean         std  min   25%    50%     75%       max
# Class
# 0      284315.0   88.291022  250.105092  0.0  5.65  22.00   77.05  25691.16
# 1         492.0  122.211321  256.683288  0.0  1.00   9.25  105.89   2125.87

# %%
corr = df.corr(numeric_only=True)["Class"].sort_values(ascending=False)
print(corr)

plt.figure(figsize=(8, 10))
corr.drop("Class").plot(kind="barh")
plt.title("Feature Correlation with Fraud (Class)")
plt.show()
# Out:
# Class     1.000000
# V11       0.154876
# V4        0.133447
# V2        0.091289
# V21       0.040413
# V19       0.034783
# V20       0.020090
# V8        0.019875
# V27       0.017580
# V28       0.009536
# Amount    0.005632
# V26       0.004455
# V25       0.003308
# V22       0.000805
# V23      -0.002685
# V15      -0.004223
# V13      -0.004570
# V24      -0.007221
# Time     -0.012323
# V6       -0.043643
# V5       -0.094974
# V9       -0.097733
# V1       -0.101347
# V18      -0.111485
# V7       -0.187257
# V3       -0.192961
# V16      -0.196539
# V10      -0.216883
# V12      -0.260593
# V14      -0.302544
# V17      -0.326481
# Name: Class, dtype: float64

# %%
## Key findings
- Dataset: 284,807 transactions, 30 features (Time, V1–V28 PCA components, Amount) + target (Class)
- Severe class imbalance: 0.173% fraud (492 cases) vs 99.827% legitimate
- No missing values
- Fraudulent transactions show a different amount distribution than legitimate ones
- V17, V14, V12, V10 (etc.) show the strongest correlation with fraud
- Given the imbalance, evaluation must prioritize precision/recall/PR-AUC over accuracy
